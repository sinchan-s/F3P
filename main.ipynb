# %%
import pandas as pd

# %%
df = pd.read_csv("Physical data with coverage.csv")
df
# Out:
#       Article No. Pattern   Shade No. WarpCount-WeftCount    EPI   PPI  \
# 0           11649   CT+PF  1000067791           16OE*12OE  106.0  56.0
# 1           11649   CT+PF  1000067791           16OE*12OE  106.0  56.0
# 2           11649   CT+PF  7000070192           16OE*12OE  106.0  56.0
# 3           11649   CT+PF  1000067791           16OE*12OE  106.0  56.0
# 4           11649   CT+PF  1000067791           16OE*12OE  106.0  56.0
# ...           ...     ...         ...                 ...    ...   ...
# 20970    C1600229  CV+5AB  000000000P      60COM*40COM.CV   90.0  64.0
# 20971    C1600229  CV+5AB  000000000P      60COM*40COM.CV   90.0  64.0
# 20972    C1600229  CV+5AB  RFP0000000      60COM*40COM.CV   90.0  64.0
# 20973    C160M450  TCS+SF  1000072811     60CT*30SPX(40D)  176.0  90.0
# 20974    C160M450  TCS+SF  8000174944     60CT*30SPX(40D)  176.0  90.0
#
#         Width        Weave Print Design Print Color  ... Weft Slippage  \
# ...

# %%
df[df['Article No.']=='13200046']
# Out:
#      Article No. Pattern   Shade No.   WarpCount-WeftCount   EPI   PPI  Width  \
# 7496    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7497    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7498    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7499    13200046  CV+5DA  1000077981  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7500    13200046  CV+5DA  1000078051  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# ...          ...     ...         ...                   ...   ...   ...    ...
# 7852    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7853    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7854    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7855    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
# 7856    13200046  CV+5DA  RFP0000000  32K.COM*32K.COM.VIS   63.0  48.0  179.5
#
# ...
