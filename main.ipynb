# %%
import pandas as pd

# %%
df = pd.read_csv("Physical data with coverage.csv")
df
# Out:
#       Article No. Pattern   Shade No. WarpCount-WeftCount EPI-PPI   Width  \
# 0           11649   CT+PF  1000067791           16OE*12OE  106*56  158.00
# 1           11649   CT+PF  1000067791           16OE*12OE  106*56  158.00
# 2           11649   CT+PF  7000070192           16OE*12OE  106*56  158.00
# 3           11649   CT+PF  1000067791           16OE*12OE  106*56  158.00
# 4           11649   CT+PF  1000067791           16OE*12OE  106*56  158.00
# ...           ...     ...         ...                 ...     ...     ...
# 20970    C1600229  CV+5AB  000000000P      60COM*40COM.CV   90*64  179.71
# 20971    C1600229  CV+5AB  000000000P      60COM*40COM.CV   90*64  179.71
# 20972    C1600229  CV+5AB  RFP0000000      60COM*40COM.CV   90*64  179.71
# 20973    C160M450  TCS+SF  1000072811     60CT*30SPX(40D)  176*90  180.09
# 20974    C160M450  TCS+SF  8000174944     60CT*30SPX(40D)  176*90  180.09
#
#              Weave Print Design Print Color      Style  ... Weft Slippage  \
# ...

# %%
df.Pattern.unique()
# Out:
# array(['CT+PF', 'CT+SF', 'CT+UVMM', 'CT+AB', 'CT+PDA', 'CT+PDALUF',
#        'ST+PF', 'ST+SF', 'CT+8ET', 'CT+8WF', 'CT+ET', 'CT+8GSF',
#        'CT+AMT6S', 'CT+PAMT6S', 'PC+SF', 'PC+WF', 'JCT+SF', 'JCT+5SF',
#        'CT+DA', 'CT+SCL', 'CT+CH', 'ST+BRDA', 'CT+8PDA', 'CT+8PF',
#        'CT+PNF', 'CT+8SF', 'ST+KPF', 'ST+PNF', 'ST+PST', 'ST+PCH',
#        'ST+8SF', 'ST+AMT6S', 'ST+DA', 'CT+PAB', 'ST+8GSF', 'ST+8DA',
#        'CT+8ET2', 'CT+8AB', 'CT+8AMT6S', 'CT+8SP', 'ST+8ET', 'ST+AB',
#        'ST+8AV', 'JCM+SF', 'JCM+DA', 'CT+KSF', 'ST+8PF', 'SPC+SF',
#        'SPC+PET', 'CT+LUF', 'CV+5DA', 'CT+72RCDA', 'SPC+OSF', 'BST+PAB',
#        'CT+5SF', 'CV+5RF', 'CV+5SF', 'JV+DA', 'V+5JDA', 'V+5GDA',
#        'JCV+SF', 'CV+5AB', 'JCV+DA', 'JCT+XF', 'PC+OPF', 'JV+SF', 'ST+WF',
#        'CT+NF', 'TC+SF', 'JM+DA', 'JM+SF', 'CT+ZF', 'CT+SL', 'CL+SF',
#        'PC+7SF', 'PC+CH', 'CT+BPF', 'CT+PST', 'ST+PDA', 'ST+PAB',
#        'CT+RDA', 'ST+8ET2', 'ST+8WF', 'ST+8AMT6S', 'ST+ET', 'SPC+PCH',
# ...
